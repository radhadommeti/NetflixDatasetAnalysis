# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('/Users/radharamyakrishnadommeti/Desktop/Netflix-Data-Analysis-master/netflix_titles.csv')

# %%
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
data.head() #to show top 5 records of the dataset
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.tail() #function to show bottom 5 records of the dataset
# Out:
#        show_id     type                                        title director  \
# 6229  80000063  TV Show                                 Red vs. Blue      NaN
# 6230  70286564  TV Show                                        Maron      NaN
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
# 6233  70153404  TV Show                                      Friends      NaN
#
#                                                    cast         country  \
# 6229  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...   United States
# 6230  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...   United States
# 6231                                                NaN             NaN
# 6232  Daniel Radcliffe, Jon Hamm, Adam Godley, Chris...  United Kingdom
# 6233  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...   United States
#
#      date_added  release_year rating    duration  \
# ...

# %%
data.shape  #to show the number of rows and columns
# Out:
# (6234, 12)

# %%
data.size   #shows the number of elemnts in the dataset
# Out:
# 74808

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   object
#  2   title         6234 non-null   object
#  3   director      4265 non-null   object
#  4   cast          5664 non-null   object
#  5   country       5758 non-null   object
#  6   date_added    6223 non-null   object
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   object
#  9   duration      6234 non-null   object
#  10  listed_in     6234 non-null   object
#  11  description   6234 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 584.6+ KB

# %% [markdown]
# # Checking If they are any duplicates and deleteing them.

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.drop_duplicates() #for removing duplicates but my dataset has no duplicates so it is just showing the column names
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %% [markdown]
# # Using heat map to check null value count

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False  False    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False      True  False    False       False
# 3       False  False  False      True  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 6229    False  False  False      True  False    False        True
# 6230    False  False  False      True  False    False        True
# 6231    False  False  False      True   True     True        True
# 6232    False  False  False      True  False    False        True
# 6233    False  False  False      True  False    False        True
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()  #null values on each column
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Getting the details of the Netflix show "DARK"

# %%
data['title']
# Out:
# 0           Norm of the North: King Sized Adventure
# 1                        Jandino: Whatever it Takes
# 2                                Transformers Prime
# 3                  Transformers: Robots in Disguise
# 4                                      #realityhigh
#                            ...
# 6229                                   Red vs. Blue
# 6230                                          Maron
# 6231         Little Baby Bum: Nursery Rhyme Friends
# 6232    A Young Doctor's Notebook and Other Stories
# 6233                                        Friends
# Name: title, Length: 6234, dtype: object

# %%
data[data['title'].isin(['Dark'])]  #to show the record of a particular item in any column
# Out:
#        show_id     type title director  \
# 5892  80100172  TV Show  Dark      NaN
#
#                                                    cast  \
# 5892  Louis Hofmann, Oliver Masucci, Jördis Triebel,...
#
#                      country      date_added  release_year rating   duration  \
# 5892  Germany, United States   June 21, 2019          2019  TV-MA  2 Seasons
#
#                                               listed_in  \
# 5892  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             description
# 5892  A missing child sets four families on a franti...

# %%
data[data['title'].str.contains('Dark')]
# Out:
#        show_id     type                                              title  \
# 91    80157072    Movie                                      Hold the Dark
# 138   80211380    Movie                                        In Darkness
# 253   80238013    Movie  The Crystal Calls Making the Dark Crystal: Age...
# 525   80081372    Movie                        A Tale of Love and Darkness
# 685   80992769    Movie                                        Dark Crimes
# 1208  70135899    Movie                        Don't Be Afraid of the Dark
# 1247  80171561  TV Show                                   Shot in the Dark
# 1831    419733    Movie                                   The Dark Crystal
# 2529  81092491    Movie        Hikaru Utada Laughter in the Dark Tour 2018
# 2556  80231601    Movie                                   The Darkest Dawn
# 2790  81078217  TV Show                                        In The Dark
# ...

# %% [markdown]
# # Showing the Bar Graph Visualisation of the highest number of TV Shows & Movies released in particular year

# %%
data.dtypes
# Out:
# show_id          int64
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Date_N']= pd.to_datetime(data['release_year'])

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.dtypes
# Out:
# show_id                  int64
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 1970    6234
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Count plot of movies and TV shows

# %%
data.groupby('type').type.count #to show all unique items of a column
# Out:
# <bound method SeriesGroupBy.count of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7fdb28e14cd0>>

# %%
sns.countplot(data['type'])
# Out:
# /Users/radharamyakrishnadommeti/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# # Data of the TV shows of the country Germany only.

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data [(data['type'] == 'TV Show') & (data['country'] == 'Germany')]
# Out:
#        show_id     type                            title director  \
# 1174  81011957  TV Show                  Holiday Secrets      NaN
# 1604  80218448  TV Show  How to Sell Drugs Online (Fast)      NaN
# 2779  80104622  TV Show             NSU German History X      NaN
# 4119  80189522  TV Show                   Dogs of Berlin      NaN
# 4394  80200596  TV Show                          Perfume      NaN
# 5367  80178971  TV Show                          Charité      NaN
# 6041  80136321  TV Show                   Babylon Berlin      NaN
#
#                                                    cast  country  \
# 1174  Corinna Harfouch, Christiane Paul, Svenja Jung...  Germany
# 1604  Maximilian Mundt, Danilo Kamperidis, Lena Klen...  Germany
# 2779  Anna Maria Mühe, Albrecht Schuch, Sebastian Ur...  Germany
# 4119  Felix Kramer, Fahri Yardim, Anna Maria Mühe, K...  Germany
# 4394  Friederike Becht, August Diehl, Wotan Wilke Mö...  Germany
# ...

# %%
data [(data['type'] == 'TV Show') & (data['country'] == 'Germany')] ['title'] #only the title
# Out:
# 1174                    Holiday Secrets
# 1604    How to Sell Drugs Online (Fast)
# 2779               NSU German History X
# 4119                     Dogs of Berlin
# 4394                            Perfume
# 5367                            Charité
# 6041                     Babylon Berlin
# Name: title, dtype: object

# %% [markdown]
# # Results of top 10 Directors

# %%
data['director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              14
# Jay Karas                 13
# Jay Chapman               12
# Martin Scorsese            9
# Steven Spielberg           9
# Lance Bangs                8
# Johnnie To                 8
# David Dhawan               8
# Hakan Algül                7
# Name: director, dtype: int64

# %%
data [(data['type'] == 'TV Show') & (data['country'] == 'United Kingdom')]
# Out:
#        show_id     type                                        title director  \
# 72    80181555  TV Show                   The Royal House of Windsor      NaN
# 83    80199032  TV Show   Paul Hollywood's Big Continental Road Trip      NaN
# 193   80136785  TV Show                                Forget Me Not      NaN
# 205   80165072  TV Show                             Click for Murder      NaN
# 227   80241102  TV Show     Cabins in the Wild with Dick Strawbridge      NaN
# ...        ...      ...                                          ...      ...
# 6180  70250398  TV Show                                        Vexed      NaN
# 6186  70258489  TV Show                                        Derek      NaN
# 6190  80130911  TV Show                                  Chewing Gum      NaN
# 6204  80091341  TV Show                                       Cuckoo      NaN
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories      NaN
#
# ...

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data[data['cast'] == 'Tom Cruise'] #Shows the result of a particular cast no results in my data set
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N]
# Index: []

# %% [markdown]
# # Dropping the null values

# %%
data_new = data.dropna()

# %%
data_new.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 4                             United States  September 8, 2017          2017
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 4  TV-14   99 min                            Comedies
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#        show_id   type     title              director  \
# 3071  60029369  Movie  Rain Man        Barry Levinson
# 3538  60000440  Movie  Magnolia  Paul Thomas Anderson
#
#                                                    cast        country  \
# 3071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
# 3538  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
#
#            date_added  release_year rating duration  \
# 3071     July 1, 2019          1988      R  134 min
# 3538  January 1, 2020          1999      R  189 min
#
#                        listed_in  \
# 3071      Classic Movies, Dramas
# 3538  Dramas, Independent Movies
#
#                                             description  \
# 3071  A fast-talking yuppie is forced to slow down w...
# 3538  Through chance, human action, past history and...
#
#                             Date_N
# 3071 1970-01-01 00:00:00.000001988
# 3538 1970-01-01 00:00:00.000001999

# %% [markdown]
# # Different ratings defined by Netflix

# %%
data['rating'].nunique()
# Out:
# 14

# %%
data['rating'].unique()
# Out:
# array(['TV-PG', 'TV-MA', 'TV-Y7-FV', 'TV-Y7', 'TV-14', 'R', 'TV-Y', 'NR',
#        'PG-13', 'TV-G', 'PG', 'G', nan, 'UR', 'NC-17'], dtype=object)

# %% [markdown]
# # Movies that are rated TV-14 in Germany

# %%
data [(data['type'] == 'Movie') & (data['rating'] == 'TV-14')]
# Out:
#        show_id   type                          title          director  \
# 4     80125979  Movie                   #realityhigh  Fernando Lebrija
# 20    80060297  Movie              Manhattan Romance       Tom O'Brien
# 36    81113928  Movie          Care of Kancharapalem    Maha Venkatesh
# 37    81052275  Movie          Ee Nagaraniki Emaindi   Tharun Bhascker
# 38    81132437  Movie            Kill Me If You Dare      Şenol Sönmez
# ...        ...    ...                            ...               ...
# 5550  80131414  Movie                Born to Be Free  Gayane Petrosyan
# 5559  80081955  Movie           Five Nights in Maine      Maris Curran
# 5560  80164112  Movie  Joe Cocker: Mad Dog with Soul     John Edginton
# 5562  70302835  Movie                          Killa      Avinash Arun
# 5568  80158479  Movie                      Salaakhen         A. Salaam
#
#                                                    cast  \
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# ...

# %%
data [(data['type'] == 'Movie') & (data['rating'] == 'TV-14') & (data['country']== 'Germany')]
# Out:
#        show_id   type                           title  \
# 1574  70118125  Movie                       My Fuhrer
# 2369  80158247  Movie                Schubert In Love
# 4324  80136332  Movie                 The NSU-Complex
# 4333  80141781  Movie   Bibi & Tina: Tohuwabohu Total
# 5418  80141253  Movie                  Bibi & Tina II
# 5419  80141254  Movie  Bibi & Tina: Girls Versus Boys
# 5464  81021447  Movie                     The Silence
#
#                      director  \
# 1574                Dani Levy
# 2369              Lars Büchel
# 4324  Stefan Aust, Dirk Laabs
# 4333              Detlev Buck
# 5418              Detlev Buck
# 5419              Detlev Buck
# 5464         John R. Leonetti
#
#                                                    cast  country  \
# 1574  Helge Schneider, Ulrich Mühe, Sylvester Groth,...  Germany
# 2369  Olaf Schubert, Mario Adorf, Marie Leuenberger,...  Germany
# 4324                                                NaN  Germany
# ...

# %%
data [(data['type'] == 'TV show') & (data['rating'] == 'R') & (data['release_year']== '2018')] #rating R Tv shows in 2018
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N]
# Index: []

# %%
data.duration.unique()
# Out:
# array(['90 min', '94 min', '1 Season', '99 min', '110 min', '60 min',
#        '78 min', '95 min', '58 min', '62 min', '65 min', '61 min',
#        '135 min', '98 min', '96 min', '79 min', '113 min', '80 min',
#        '77 min', '112 min', '106 min', '102 min', '114 min', '125 min',
#        '142 min', '133 min', '100 min', '86 min', '146 min', '10 min',
#        '122 min', '126 min', '116 min', '130 min', '70 min', '128 min',
#        '88 min', '108 min', '93 min', '64 min', '107 min', '92 min',
#        '111 min', '103 min', '40 min', '85 min', '72 min', '45 min',
#        '89 min', '24 min', '127 min', '163 min', '117 min', '42 min',
#        '104 min', '75 min', '82 min', '38 min', '97 min', '81 min',
#        '91 min', '152 min', '87 min', '121 min', '101 min', '119 min',
#        '83 min', '182 min', '124 min', '63 min', '139 min', '171 min',
#        '84 min', '69 min', '76 min', '41 min', '153 min', '141 min',
# ...

# %%
data.duration.dtype
# Out:
# dtype('O')

# %%
data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand = True) #creating two diff columns by splitting a single column

# %%
data.head(2)
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
# 1  TV-MA   94 min                     Stand-Up Comedy
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# ...

# %%
data['Minutes']
# Out:
# 0       90
# 1       94
# 2        1
# 3        1
# 4       99
#         ..
# 6229    13
# 6230     4
# 6231    60
# 6232     2
# 6233    10
# Name: Minutes, Length: 6234, dtype: object

# %%
data['Minutes'].min()
# Out:
# '1'

# %%
data['Minutes'].max()
# Out:
# '99'

# %%
data['Minutes'].mean()
# Out:
# inf

# %%
data_tvshow = data[data['title']== 'Movie']

# %%
data_tvshow.head()
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N, Minutes, Unit]
# Index: []

# %%
data_tvshow.country.value_counts()
# Out:
# Series([], Name: country, dtype: int64)

# %% [markdown]
# # Sorting the dataset by year

# %%
data.sort_values(by = 'release_year')
# Out:
#        show_id     type                                          title  \
# 4292  81030762  TV Show              Pioneers: First Women Filmmakers*
# 2011  60027945    Movie                                 Prelude to War
# 2013  60027942    Movie                           The Battle of Midway
# 2022  80119186    Movie  Undercover: How to Operate Behind Enemy Lines
# 2023  70013050    Movie             Why We Fight: The Battle of Russia
# ...        ...      ...                                            ...
# 3189  81039393  TV Show                                          Cheer
# 3180  81214114    Movie                                  Bulletproof 2
# 1315  81034946  TV Show                             Maradona in Mexico
# 3379  81062828  TV Show     Killer Inside: The Mind of Aaron Hernandez
# 3464  80237329  TV Show                               AJ and the Queen
#
#                          director  \
# 4292                          NaN
# 2011                  Frank Capra
# ...

# %%
data.sort_values(by = 'release_year' , ascending = False)
# Out:
#        show_id     type                                          title  \
# 3467  81011449  TV Show                                 Medical Police
# 3249  81006825    Movie                  All the Freckles in the World
# 3220  80997687  TV Show                                        Dracula
# 3427  81060049    Movie                     Leslie Jones: Time Machine
# 3436  80239306  TV Show                     The Healing Powers of Dude
# ...        ...      ...                                            ...
# 2023  70013050    Movie             Why We Fight: The Battle of Russia
# 2022  80119186    Movie  Undercover: How to Operate Behind Enemy Lines
# 2013  60027942    Movie                           The Battle of Midway
# 2011  60027945    Movie                                 Prelude to War
# 4292  81030762  TV Show              Pioneers: First Women Filmmakers*
#
#                          director  \
# 3467                          NaN
# 3249                 Yibrán Asuad
# ...
